# %% [markdown]
# # Cleaning US Census Data

# %% [markdown]
# You just got hired as a Data Analyst at the Census Bureau, which collects census data and creates interesting visualizations and insights from it.
#
# The person who had your job before you left you all the data they had for the most recent census. It is in multiple `csv` files. They didn't use pandas, they would just look through these `csv` files manually whenever they wanted to find something. Sometimes they would copy and paste certain numbers into Excel to make charts.
#
# The thought of it makes you shiver. This is not scalable or repeatable.
#
# Your boss wants you to make some scatterplots and histograms by the end of the day. Can you get this data into `pandas` and into reasonable shape so that you can make these histograms?

# %% [markdown]
# ## Inspect the Data!

# %% [markdown]
# 1. The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.
#
#    Open some of the census `csv` files that came with the kit you downloaded. How are they named? What kind of information do they hold? Will they help us make this graph?

# %%
import glob

globber = glob.glob("state*.csv")

list_of_files = []
for each_file in globber:
    list_of_files.append(pd.read_csv(each_file))

df = pd.concat(list_of_files)

df = df.sort_values(by="State")

# %% [markdown]
# 2. It will be easier to inspect this data once we have it in a DataFrame. You can't even call `.head()` on these `csv`s! How are you supposed to read them?
#
#    Using `glob`, loop through the census files available and load them into DataFrames. Then, concatenate all of those DataFrames together into one DataFrame, called something like `us_census`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

globber = glob.glob("state*.csv")

list_of_files = []
for each_file in globber:
    list_of_files.append(pd.read_csv(each_file))

df = pd.concat(list_of_files)

df = df.sort_values(by="State")

# %% [markdown]
# 3. Look at the `.columns` and the `.dtypes` of the `us_census` DataFrame. Are those datatypes going to hinder you as you try to make histograms?

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
df.drop(columns = "Unnamed: 0", inplace=True)

# %%
df.dtypes
# Out:
# State        object
# TotalPop      int64
# Hispanic     object
# White        object
# Black        object
# Native       object
# Asian        object
# Pacific      object
# Income       object
# GenderPop    object
# dtype: object

# %% [markdown]
# 4. Look at the `head()` of the DataFrame so that you can understand why some of these `dtypes` are objects instead of integers or floats.
#
#    Start to make a plan for how to convert these columns into the right types for manipulation.

# %%
df.head()
# Out:
#         State  TotalPop Hispanic   White   Black  Native   Asian Pacific  \
# 0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%   0.03%
# 1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%   1.06%
# 2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%   0.17%
# 3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%   0.15%
# 4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%   0.35%
#
#         Income            GenderPop
# 0  $43,296.36     2341093M_2489527F
# 1  $70,354.74       384160M_349215F
# 2  $54,207.82     3299088M_3342840F
# 3  $41,935.63     1451913M_1506295F
# 4  $67,264.78   19087135M_19334329F

# %% [markdown]
# ## Regex to the Rescue

# %% [markdown]
# 5. Use regex to turn the `Income` column into a format that is ready for conversion into a numerical type.

# %%
df.Income = df.Income.replace('[\$,]', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/75/8cznfb4d2j56mrdwqyh36s3w0000gn/T/ipykernel_13109/4210018751.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df.Income = df.Income.replace('[\$,]', '', regex=True)

# %%
df.Income = df.Income.astype(float)

# %% [markdown]
# 6. Look at the `GenderPop` column. We are going to want to separate this into two columns, the `Men` column, and the `Women` column.
#
#    Split the column into those two new columns using `str.split` and separating out those results.

# %%
split_df = df.GenderPop.str.split('(\d+)', expand=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/75/8cznfb4d2j56mrdwqyh36s3w0000gn/T/ipykernel_13109/3376499298.py:1: SyntaxWarning: invalid escape sequence '\d'
#   split_df = df.GenderPop.str.split('(\d+)', expand=True)

# %%
split_df.drop(columns=0,inplace=True)

# %%
df[["MalePop", "Male", "FemalePop", "Female"]] = split_df

# %%
df.drop(columns = ["GenderPop","Male","Female"], inplace=True)

# %% [markdown]
# 7. Convert both of the columns into numerical datatypes.
#
#    There is still an `M` or an `F` character in each entry! We should remove those before we convert.

# %%
df.MalePop = df.MalePop.astype(int)

# %%
df.FemalePop = df.FemalePop.fillna(0)

# %%
df.FemalePop = df.FemalePop.astype(int)

# %%
for each in df.FemalePop:
    print(type(each))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'NoneType'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'NoneType'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
df
# Out:
#                    State  TotalPop Hispanic   White   Black  Native   Asian  \
# 0                Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%
# 1                 Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%
# 2                Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%
# 3               Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%
# 4             California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%
# 5               Colorado   5278906   20.78%  69.90%   3.55%   0.57%   2.66%
# 6            Connecticut   3593222   15.60%  67.68%  10.35%   0.13%   4.02%
# 7               Delaware    926454    8.82%  64.63%  20.74%   0.26%   3.27%
# 8   District of Columbia    647484    9.17%  33.10%  51.78%   0.20%   3.38%
# 9                Florida  19645772   21.34%  59.08%  15.17%   0.21%   2.28%
# 10               Georgia  10006693    8.42%  54.29%  32.09%   0.19%   3.10%
# ...

# %% [markdown]
# 8. Now you should have the columns you need to make the graph and make sure your boss does not slam a ruler angrily on your desk because you've wasted your whole day cleaning your data with no results to show!
#
#    Use matplotlib to make a scatterplot!
#
#    ```py
#    plt.scatter(the_women_column, the_income_column)
#    ```
#
#    Remember to call `plt.show()` to see the graph!

# %%
plt.scatter(df.FemalePop, df.Income)

# %% [markdown]
# 9. You want to double check your work. You know from experience that these monstrous csv files probably have `nan` values in them! Print out your column with the number of women per state to see.
#
#    We can fill in those `nan`s by using pandas' `.fillna()` function.
#
#    You have the `TotalPop` per state, and you have the `Men` per state. As an estimate for the `nan` values in the `Women` column, you could use the `TotalPop` of that state minus the `Men` for that state.
#
#    Print out the `Women` column after filling the `nan` values to see if it worked!

# %%
df.head(3)
# Out:
#      State  TotalPop Hispanic   White   Black  Native  Asian Pacific  \
# 0  Alabama   4830620    3.75%  61.88%  31.25%   0.45%  1.05%   0.03%
# 1   Alaska    733375    5.91%  60.91%   2.85%  16.39%  5.45%   1.06%
# 2  Arizona   6641928   29.57%  57.12%   3.85%   4.36%  2.88%   0.17%
#
#      Income  MalePop  FemalePop
# 0  43296.36  2341093    2489527
# 1  70354.74   384160     349215
# 2  54207.82  3299088    3342840

# %%
df.FemalePop = df.apply(lambda x: (x.TotalPop - x.MalePop) if x.FemalePop == 0 else x.FemalePop  , axis =1)

# %%
plt.scatter(df.FemalePop, df.Income)

# %% [markdown]
# 10. We forgot to check for duplicates! Use `.duplicated()` on your `census` DataFrame to see if we have duplicate rows in there.

# %%
df.duplicated().value_counts()
# Out:
# False    51
# Name: count, dtype: int64

# %% [markdown]
# 11. Drop those duplicates using the `.drop_duplicates()` function.

# %%
df.drop_duplicates(subset="State",inplace=True)
df = df.reset_index().drop(columns="index")

# %% [markdown]
# 12. Make the scatterplot again. Now, it should be perfect! Your job is secure, for now.

# %%
plt.scatter(df.Income, df.FemalePop)

# %% [markdown]
# ## Histogram of Races

# %% [markdown]
# 13. Now your boss wants you to make a bunch of histograms out of the race data that you have. Look at the `.columns` again to see what the race categories are.

# %%
df.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'MalePop', 'FemalePop'],
#       dtype='object')

# %%
df.head(3)
# Out:
#      State  TotalPop Hispanic   White   Black  Native  Asian Pacific  \
# 0  Alabama   4830620    3.75%  61.88%  31.25%   0.45%  1.05%   0.03%
# 1   Alaska    733375    5.91%  60.91%   2.85%  16.39%  5.45%   1.06%
# 2  Arizona   6641928   29.57%  57.12%   3.85%   4.36%  2.88%   0.17%
#
#      Income  MalePop  FemalePop
# 0  43296.36  2341093    2489527
# 1  70354.74   384160     349215
# 2  54207.82  3299088    3342840

# %% [markdown]
# 14. Try to make a histogram for each one!
#
#     You will have to get the columns into the numerical format, and those percentage signs will have to go.
#
#     Don't forget to fill the `nan` values with something that makes sense! You probably dropped the duplicate rows when making your last graph, but it couldn't hurt to check for duplicates again.

# %%
for each_column in df.iloc[:,2:-3].columns:
    df[each_column] = df[each_column].str.strip("%").astype(float)

# %%
df.isnull().sum()
# Out:
# State        0
# TotalPop     0
# Hispanic     0
# White        0
# Black        0
# Native       0
# Asian        0
# Pacific      4
# Income       0
# MalePop      0
# FemalePop    0
# dtype: int64

# %% [markdown]
# Thought Process:
#
# Find the remaining population percent
#
# 100 - existing population percent
#
# Estimate that 25% of population gap is Pacific
#
# Fill Nulls in Pacific with 25% of the remaining population in that state
#
# NOTE: Pacific population for a specific state is highly correlated with Asian population for a state.
# This could be a good candidate to fill in Null values based on linear interpolation

# %%
df["pacific_pop_estimate"] = df.apply(lambda x:  (100 - (x.Hispanic + x.White + x.Black + x.Native + x.Asian)) * 0.25, axis=1)

# %%
df.loc[(df.Pacific.isnull())].apply(lambda x: x.fillna(x.pacific_pop_estimate), axis=1)
# Out:
# Empty DataFrame
# Columns: [State, TotalPop, Hispanic, White, Black, Native, Asian, Pacific, Income, MalePop, FemalePop, non_pacific_pop, pacific_pop_estimate]
# Index: []

# %%
df.loc[(df.Pacific.isnull())] = df.loc[(df.Pacific.isnull())].apply(lambda x: x.fillna(x.pacific_pop_estimate), axis=1)

# %%
df.isnull().sum()
# Out:
# State                   0
# TotalPop                0
# Hispanic                0
# White                   0
# Black                   0
# Native                  0
# Asian                   0
# Pacific                 0
# Income                  0
# MalePop                 0
# FemalePop               0
# non_pacific_pop         0
# pacific_pop_estimate    0
# dtype: int64

# %%
df = df.drop(columns = ["non_pacific_pop", "pacific_pop_estimate"])

# %%
df.corr(numeric_only=True)
# Out:
#                       TotalPop  Hispanic     White     Black    Native  \
# TotalPop              1.000000  0.283525 -0.297047  0.100797 -0.248176
# Hispanic              0.283525  1.000000 -0.709392 -0.216488  0.000186
# White                -0.297047 -0.709392  1.000000 -0.341264  0.027205
# Black                 0.100797 -0.216488 -0.341264  1.000000 -0.309856
# Native               -0.248176  0.000186  0.027205 -0.309856  1.000000
# Asian                 0.185682  0.046918 -0.424827 -0.102373 -0.089420
# Pacific              -0.112024 -0.026552 -0.328124 -0.171839  0.015407
# Income                0.120422 -0.232250 -0.013260  0.008675  0.003762
# MalePop               0.999921  0.284258 -0.295883  0.095790 -0.245196
# FemalePop             0.999925  0.282767 -0.298137  0.105663 -0.251043
# non_pacific_pop       0.107280  0.090290  0.285575  0.183803 -0.146523
# pacific_pop_estimate -0.107280 -0.090290 -0.285575 -0.183803  0.146523
#
# ...

# %%
df.hist(bins=30, figsize=(20,20));

# %% [markdown]
# ## Get Creative

# %% [markdown]
# 15. Phew. You've definitely impressed your boss on your first day of work.
#
#     But is there a way you really convey the power of pandas and Python over the drudgery of `csv` and Excel?
#
#     Try to make some more interesting graphs to show your boss, and the world! You may need to clean the data even more to do it, or the cleaning you have already done may give you the ease of manipulation you've been searching for.

# %%
df[(df.Hispanic > 25)]
# Out:
#           State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 2       Arizona   6641928     29.57  57.12   3.85    4.36   2.88     0.17
# 4    California  38421464     37.29  40.22   5.68    0.41  13.05     0.35
# 28       Nevada   2798636     27.10  53.24   7.74    1.09   7.10     0.57
# 31   New Mexico   2084117     45.28  40.70   1.76    9.25   1.23     0.04
# 39  Puerto Rico   3583073     98.89   0.77   0.09    0.00   0.08     0.00
# 44        Texas  26538614     38.05  44.69  11.65    0.26   3.67     0.07
#
#       Income   MalePop  FemalePop
# 2   54207.82   3299088    3342840
# 4   67264.78  19087135   19334329
# 28  55526.53   1407735    1390901
# 31  47329.97   1032414    1051703
# 39  20720.54   1713860    1869213
# 44  55874.52  13171316   13367298

# %%
df[(df.Pacific > 1)]
# Out:
#      State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 1   Alaska    733375      5.91  60.91   2.85   16.39   5.45     1.06
# 11  Hawaii   1406299      9.19  25.03   2.05    0.14  36.59     8.76
#
#       Income  MalePop  FemalePop
# 1   70354.74   384160     349215
# 11  73264.43   709871     696428

# %%
df["PercentFemale"] = df.apply(lambda x: round((x.FemalePop/x.TotalPop)* 100,2), axis=1)

# %%
df[df.PercentFemale > 50]
# Out:
#                    State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0                Alabama   4830620      3.75  61.88  31.25    0.45   1.05
# 2                Arizona   6641928     29.57  57.12   3.85    4.36   2.88
# 3               Arkansas   2958208      6.22  71.14  18.97    0.52   1.14
# 4             California  38421464     37.29  40.22   5.68    0.41  13.05
# 6            Connecticut   3593222     15.60  67.68  10.35    0.13   4.02
# 7               Delaware    926454      8.82  64.63  20.74    0.26   3.27
# 8   District of Columbia    647484      9.17  33.10  51.78    0.20   3.38
# 9                Florida  19645772     21.34  59.08  15.17    0.21   2.28
# 10               Georgia  10006693      8.42  54.29  32.09    0.19   3.10
# 13              Illinois  12873761     15.60  60.86  17.11    0.12   4.48
# 14               Indiana   6568645      6.54  78.43  11.19    0.19   1.58
# 15                  Iowa   3093526      5.30  87.72   3.26    0.29   1.70
# ...

# %%
df["PercentMale"] = df.apply(lambda x: round((x.MalePop/x.TotalPop)* 100,2), axis=1)

# %%
df[df.PercentMale > 50].count()
# Out:
# State            9
# TotalPop         9
# Hispanic         9
# White            9
# Black            9
# Native           9
# Asian            9
# Pacific          9
# Income           9
# MalePop          9
# FemalePop        9
# PercentFemale    9
# PercentMale      9
# dtype: int64

# %%
total_female = df.FemalePop.sum()

# %%
total_female
# Out:
# 162365836

# %%
total_male = df.MalePop.sum()

# %%
round((total_female / (total_male + total_female))* 100, 2)
# Out:
# 50.82

# %%
plt.xlim(0, 15)
plt.ylim(0,2)
plt.scatter(df.Asian, df.Pacific)

# %%
#df[["State", "Income"]].sort_values(by="Income", ascending=False)

# %%
#df[["State", "TotalPop"]].sort_values(by="TotalPop", ascending=False)
# Out:
#                    State  TotalPop
# 4             California  38421464
# 44                 Texas  26538614
# 32              New York  19673174
# 9                Florida  19645772
# 13              Illinois  12873761
# 38          Pennsylvania  12779559
# 35                  Ohio  11575977
# 10               Georgia  10006693
# 22              Michigan   9900571
# 33        North Carolina   9845333
# 30            New Jersey   8904413
# 47              Virginia   8256630
# 48            Washington   6985464
# 21         Massachusetts   6705586
# 2                Arizona   6641928
# 14               Indiana   6568645
# 43             Tennessee   6499615
# 25              Missouri   6045448
# 20              Maryland   5930538
# 50             Wisconsin   5742117
# 23             Minnesota   5419171
# 5               Colorado   5278906
# 0                Alabama   4830620
# 41        South Carolina   4777576
# 18             Louisiana   4625253
# 17              Kentucky   4397353
# ...
